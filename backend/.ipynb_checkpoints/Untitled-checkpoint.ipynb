# %%
import pandas as pd


all = pd.read_csv('./data/battersAll.csv')

def page(i):
    all2 = all.sort_values(by=['타석'], ascending=False)[(i-1)*30:i*30]
    print(all2)
# Out:
#         이름     순   팀/포지션   정렬용      G     타석     타수     득점     안타   2루타  ...  \
# 350    홍창기   6.0   23LRF  5.17  141.0  643.0  524.0  109.0  174.0  35.0  ...
# 98     김혜성   2.0   23키2B  6.19  137.0  621.0  556.0  104.0  186.0  29.0  ...
# 173    손아섭   9.0   23NDH  4.39  140.0  609.0  551.0   97.0  187.0  36.0  ...
# 170  소크라테스   8.0   23KCF  4.58  142.0  608.0  547.0   91.0  156.0  31.0  ...
# 333    피렐라  38.0   23삼LF  2.44  139.0  605.0  557.0   66.0  159.0  28.0  ...
# 309    채은성  34.0   23한1B  2.64  137.0  596.0  521.0   71.0  137.0  17.0  ...
# 105    노시환   1.0   23한3B  6.93  131.0  595.0  514.0   85.0  153.0  30.0  ...
# 208    오스틴   5.0   23L1B  5.22  139.0  583.0  520.0   87.0  163.0  29.0  ...
# 293    정수빈  14.0   23두CF  3.89  137.0  583.0  498.0   75.0  143.0  14.0  ...
# 198    양석환  33.0   23두1B  2.65  140.0  581.0  524.0   73.0  147.0  28.0  ...
# 289    전준우  22.0   23롯DH  3.60  138.0  559.0  493.0   80.0  154.0  21.0  ...
# ...
